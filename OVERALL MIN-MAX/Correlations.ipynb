# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

# Try reading the CSV file with a different encoding
data = pd.read_csv("cleaned_data(input).csv",encoding='ISO-8859-1')

# Display the first few rows of the dataframe to ensure it's read correctly
print(data.head())
# Out:
#                Date  Togo  Algeria  Senegal  Morocco  \
# 0  06-04-2024 02:48    40       50       10        0
# 1  06-04-2024 02:49    40       50       10        0
# 2  06-04-2024 02:50    40       50       10        0
# 3  06-04-2024 02:51    40       50       10        0
# 4  06-04-2024 02:52    40       50       10        0
#
#    Weigh_Feeder_rate_ A(TPH)  Weigh_feeder_rate_B(TPH)  Ball_mill_amps  \
# 0                  31.788508                 47.332464       81.374871
# 1                  31.791530                 47.199781       80.575081
# 2                  31.743277                 47.180855       79.518921
# 3                  31.849043                 47.264999       81.060974
# 4                  31.771549                 47.366891       81.475720
#
#    MILL_FEED_END_BRNG_TEMP(Â°C)  MILL_DISCH_END_BRNG_TEMP(Â°C)  ...  \
# 0                     45.621317                      49.254234  ...
# 1                     45.612920                      49.244208  ...
# ...

# %%
data.columns
# Out:
# Index(['Date', 'Togo', 'Algeria', 'Senegal', 'Morocco',
#        'Weigh_Feeder_rate_ A(TPH)', 'Weigh_feeder_rate_B(TPH)',
#        'Ball_mill_amps', 'MILL_FEED_END_BRNG_TEMP(Â°C)',
#        'MILL_DISCH_END_BRNG_TEMP(Â°C)',
#        ...
#        'M- (Bulk Density Kg/Cft)', '> 35', '35 to 200', '< 200', 'X1', 'X2',
#        'X3', 'X4', 'X5', 'X6'],
#       dtype='object', length=139)

# %%
from tabulate import tabulate

selected_columns =  ['Weigh_Feeder_rate_ A(TPH)', 'Weigh_feeder_rate_B(TPH)', 'Ball_mill_amps',
            'BALL_MILL_VENT_SYS_TEMP(Â°C)','BALL_MILL_VENT_FAN_AMPS', 'BAG_FILTER_DP(mmWC)',
            'SCREW_CONV _ CURRENT(Amps)','BUCKET_ELEVATOR_CURRENT(Amps)']


corr_matrix = data[selected_columns].corr()

print(tabulate(corr_matrix, headers='keys', tablefmt='fancy_grid'))

# Plot the heatmap
# plt.figure(figsize=(20, 10))  # adjust the figsize as necessary
# sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
# plt.title('Selected Feature Correlation Matrix')
# plt.show()
# Out:
# ╒═══════════════════════════════╤═════════════════════════════╤════════════════════════════╤══════════════════╤════════════════════════════════╤═══════════════════════════╤═══════════════════════╤══════════════════════════════╤═════════════════════════════════╕
# │                               │   Weigh_Feeder_rate_ A(TPH) │   Weigh_feeder_rate_B(TPH) │   Ball_mill_amps │   BALL_MILL_VENT_SYS_TEMP(Â°C) │   BALL_MILL_VENT_FAN_AMPS │   BAG_FILTER_DP(mmWC) │   SCREW_CONV _ CURRENT(Amps) │   BUCKET_ELEVATOR_CURRENT(Amps) │
# ╞═══════════════════════════════╪═════════════════════════════╪════════════════════════════╪══════════════════╪════════════════════════════════╪═══════════════════════════╪═══════════════════════╪══════════════════════════════╪═════════════════════════════════╡
# ...

# %%
# Define the index range for the columns to be accessed (5th to 42nd columns)
start_index = 5
end_index = 42

# Get the column names for the specified range
features = data.columns[start_index:end_index]

corr_matrix = data[features].corr()

print(tabulate(corr_matrix, headers='keys', tablefmt='fancy_grid'))

data.to_excel('correlation matrix(process parameters).xlsx')
# Out:
# ╒════════════════════════════════════════╤═════════════════════════════╤════════════════════════════╤══════════════════╤════════════════════════════════╤═════════════════════════════════╤════════════════════════════╤══════════════════════════════════╤═══════════════════════════════════╤═════════════════════════════╤════════════════════════════════╤═══════════════════════════╤═══════════════════════════════════════╤════════════════════╤═══════════════════════╤══════════════════════════════╤═══════════════════════════════╤══════════════════════════╤═══════════════════════╤═══════════════════════════════════╤═════════════════════════════════╤═══════════════════════════════╤═══════════════════════════════╤═══════════════════════════════╤═══════════════════════════════╤═════════════════════════════╤═════════════════════════════╤═════════════════════════════╤═════════════════════════════╤═════════════════════════════╤═════════════════════════════╤═══════════════════════════════════╤═══════
# ...

# %%
selected_columns =  ['X1', 'X2', 'X3', 'X4','X5', 'X6', '> 35', '35 to 200' , '< 200']


corr_matrix = data[selected_columns].corr()

print(tabulate(corr_matrix, headers='keys', tablefmt='fancy_grid'))

# Plot the heatmap
plt.figure(figsize=(20, 10))  # adjust the figsize as necessary
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Selected Feature Correlation Matrix')
plt.show()
# Out:
# ╒═══════════╤═══════════╤═══════════╤═══════════╤═══════════╤═══════════╤═══════════╤════════════╤═════════════╤═══════════╕
# │           │        X1 │        X2 │        X3 │        X4 │        X5 │        X6 │       > 35 │   35 to 200 │     < 200 │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══════════╪═══════════╪═══════════╪════════════╪═════════════╪═══════════╡
# │ X1        │  1        │ -1        │ -1        │ -1        │  1        │  1        │  0.243751  │  -0.512906  │  0.456694 │
# ├───────────┼───────────┼───────────┼───────────┼───────────┼───────────┼───────────┼────────────┼─────────────┼───────────┤
# │ X2        │ -1        │  1        │  1        │  1        │ -1        │ -1        │ -0.243751  │   0.512906  │ -0.456694 │
# ├───────────┼───────────┼───────────┼───────────┼───────────┼───────────┼───────────┼────────────┼─────────────┼───────────┤
# ...

# %%
target_vars = ['> 35','35 to 200', '< 200']
feature_vars = [col for col in selected_columns if col not in target_vars]

for target in target_vars:
    target_corr = data[feature_vars].corrwith(data[target])
    print(f'Correlation with {target}:')
    print(target_corr, '\n')
# Out:
# Correlation with > 35:
# X1    0.243751
# X2   -0.243751
# X3   -0.243751
# X4   -0.243751
# X5    0.243751
# X6    0.243751
# dtype: float64
#
# Correlation with 35 to 200:
# X1   -0.512906
# X2    0.512906
# X3    0.512906
# X4    0.512906
# X5   -0.512906
# X6   -0.512906
# dtype: float64
#
# Correlation with < 200:
# X1    0.456694
# X2   -0.456694
# X3   -0.456694
# X4   -0.456694
# X5    0.456694
# X6    0.456694
# dtype: float64

# %%
missing_values = data.isnull().sum()
print(missing_values)
